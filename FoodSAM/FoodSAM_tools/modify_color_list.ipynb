# %%
import numpy as np

# %%
data = np.load('color_list.npy')

# %%
for i in range(104):
    print(f'{i}: {data[i]}')
# Out:
# 0: [120 120 120]
# 1: [180 120 120]
# 2: [  6 230 230]
# 3: [80 50 50]
# 4: [  4 200   3]
# 5: [120 120  80]
# 6: [140 140 140]
# 7: [204   5 255]
# 8: [230 230 230]
# 9: [  4 250   7]
# 10: [224   5 255]
# 11: [235 255   7]
# 12: [150   5  61]
# 13: [120 120  70]
# 14: [  8 255  51]
# 15: [255   6  82]
# 16: [143 255 140]
# 17: [204 255   4]
# 18: [255  51   7]
# 19: [204  70   3]
# 20: [  0 102 200]
# 21: [ 61 230 250]
# 22: [255   6  51]
# 23: [ 11 102 255]
# 24: [255   7  71]
# 25: [255   9 224]
# 26: [  9   7 230]
# 27: [220 220 220]
# 28: [255   9  92]
# 29: [112   9 255]
# 30: [  8 255 214]
# 31: [  7 255 224]
# 32: [255 184   6]
# 33: [ 10 255  71]
# 34: [255  41  10]
# 35: [  7 255 255]
# 36: [224 255   8]
# 37: [102   8 255]
# 38: [255  61   6]
# 39: [255 194   7]
# 40: [255 122   8]
# 41: [  0 255  20]
# 42: [255   8  41]
# 43: [255   5 153]
# 44: [  6  51 255]
# 45: [235  12 255]
# 46: [160 150  20]
# 47: [  0 163 255]
# 48: [140 140 140]
# 49: [250  10  15]
# ...

# %%
data_copy = data.copy()

# %%
data_copy[26] = [200,7,230]
data_copy[44] = [200,51,255]
data_copy[59] =[200,0,255]
data_copy[75] =[0,200,255]
data_copy[85] =[200,31,255]
data_copy[91] =[200,100,255]
data_copy[93] =[20,100,255]
data_copy[101] =[82,200,255]

# %%
for i in range(104):
    print(f'{i}: {data_copy[i]}')
# Out:
# 0: [120 120 120]
# 1: [180 120 120]
# 2: [  6 230 230]
# 3: [80 50 50]
# 4: [  4 200   3]
# 5: [120 120  80]
# 6: [140 140 140]
# 7: [204   5 255]
# 8: [230 230 230]
# 9: [  4 250   7]
# 10: [224   5 255]
# 11: [235 255   7]
# 12: [150   5  61]
# 13: [120 120  70]
# 14: [  8 255  51]
# 15: [255   6  82]
# 16: [143 255 140]
# 17: [204 255   4]
# 18: [255  51   7]
# 19: [204  70   3]
# 20: [  0 102 200]
# 21: [ 61 230 250]
# 22: [255   6  51]
# 23: [ 11 102 255]
# 24: [255   7  71]
# 25: [255   9 224]
# 26: [200   7 230]
# 27: [220 220 220]
# 28: [255   9  92]
# 29: [112   9 255]
# 30: [  8 255 214]
# 31: [  7 255 224]
# 32: [255 184   6]
# 33: [ 10 255  71]
# 34: [255  41  10]
# 35: [  7 255 255]
# 36: [224 255   8]
# 37: [102   8 255]
# 38: [255  61   6]
# 39: [255 194   7]
# 40: [255 122   8]
# 41: [  0 255  20]
# 42: [255   8  41]
# 43: [255   5 153]
# 44: [200  51 255]
# 45: [235  12 255]
# 46: [160 150  20]
# 47: [  0 163 255]
# 48: [140 140 140]
# 49: [250  10  15]
# ...

# %%
np.save('color_list_v2.npy', data)
